# %% [markdown]
# ### Adding dependencies for the extract, transform and load processes.

# %%
#Dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# ### The resources includes three CSVs files namely, Asylum_seekers, demographics and time_series. These are loaded into the dataframes using pandas.

# %%
#Extracting data from csv files
asylum_seekers_monthly =pd.read_csv("Resources/asylum_seekers_monthly.csv")
asylum_seekers_monthly.sample(20)
asylum_seekers_monthly = asylum_seekers_monthly.rename(columns ={"Country / territory of asylum/residence":"host_country", 
                                                                "Origin":"origin", "Year":"year", "Month":"month", "Value":"value"})
asylum_seekers_monthly
# Out:
# C:\Users\vijet\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          host_country       origin  year     month value
# 0           Australia  Afghanistan  1999   January     8
# 1           Australia  Afghanistan  1999  February    10
# 2           Australia  Afghanistan  1999     March    25
# 3           Australia  Afghanistan  1999     April    25
# 4           Australia  Afghanistan  1999       May     7
# ...               ...          ...   ...       ...   ...
# 332184  USA (INS/DHS)     Zimbabwe  2016  December    28
# 332185  USA (INS/DHS)     Zimbabwe  2017  February    27
# 332186  USA (INS/DHS)     Zimbabwe  2017     March    42
# 332187  USA (INS/DHS)     Zimbabwe  2017     April    16
# 332188  USA (INS/DHS)     Zimbabwe  2017       May    12
#
# [332189 rows x 5 columns]

# %% [markdown]
# ### Data clean up to remove the special characters and null values in all the three datasets

# %%
#Replacing the special characters with zero.
asylum_seekers = asylum_seekers_monthly.copy()
asylum_seekers=asylum_seekers.replace(['*'], [0])
asylum_seekers.sample(20)
# Out:
#                   host_country                                origin  year  \
# 203692             Switzerland                                Guinea  2010
# 179832                   Italy                                Turkey  2009
# 292559                 Germany                               Belarus  2015
# 138589                  Canada                              Mongolia  2007
# 128806                  Norway                            Uzbekistan  2006
# 137564  Bosnia and Herzegovina  Serbia and Kosovo: S/RES/1244 (1999)  2007
# 108761                 Hungary                              Zimbabwe  2005
# 94737                 Slovakia                              Cameroon  2004
# 214265                  France                               Nigeria  2011
# 231979                 Denmark                                 Ghana  2012
# 21787                  Ireland                               Estonia  2000
# 200234                  Norway                                 China  2010
# 69220                  Denmark                         Côte d'Ivoire  2003
# 174202                  Canada                              Thailand  2009
# 220430                 Romania                         Côte d'Ivoire  2011
# 75699                   Norway                            Mauritania  2003
# 158000                  France                                Gambia  2008
# 299301           Rep. of Korea                           Philippines  2015
# 184933             Switzerland                                 Gabon  2009
# 170695               Australia                               Georgia  2009
#
#             month value
# 203692       July    22
# 179832  September    55
# 292559       July    11
# 138589    October     1
# 128806     August     3
# 137564      March     2
# 108761       June     2
# 94737       April     1
# 214265       July    59
# 231979  September     2
# 21787       April     5
# 200234    October    31
# 69220    February     1
# 174202     August     1
# 220430    January     1
# 75699       April     1
# 158000      March     1
# 299301   November    19
# 184933       July     1
# 170695     August     2

# %%
#Retrieving the column names for reference
asylum_seekers.columns
# Out:
# Index(['host_country', 'origin', 'year', 'month', 'value'], dtype='object')

# %%
#Reading the second dataset using pandas
demographics = pd.read_csv("Resources/demographics.csv")
demographics.sample(20)
# Out:
#        Year Country / territory of asylum/residence  \
# 8791   2011                                 Eritrea
# 16655  2015                                   Sudan
# 12699  2014                                   Egypt
# 8597   2011                                Cameroon
# 2974   2005                                   Nepal
# 12491  2014                                Cameroon
# 11828  2013                                Pakistan
# 1974   2004                              Czech Rep.
# 1267   2003                  Dem. Rep. of the Congo
# 2606   2005                                  Brazil
# 7234   2010                             Afghanistan
# 9469   2011                             South Sudan
# 5990   2008                                    Chad
# 13444  2014                                  Turkey
# 15079  2014                            Saudi Arabia
# 15083  2014                                 Senegal
# 12931  2014                                  Jordan
# 9475   2011                                Slovakia
# 9474   2011                                Slovakia
# 6874   2009                            Saudi Arabia
#
#                                         Location Name Female 0-4 Female 5-11  \
# 8791   Eritrea : Dispersed in the country / territory          1         NaN
# 16655                                  Eastern Darfur          0           0
# 12699                  Qena : Muhafazah - Governorate          0           2
# 8597                                     Digou Adamou         15          16
# 2974                                       Sanischare       1010         NaN
# 12491                                        Monatele          0           2
# 11828                              Pir Alizai : Point        388        1345
# 1974                                              Sec          0         NaN
# 1267                                        Mbujimayi          1         NaN
# 2606                               Mato Grosso do Sul          0         NaN
# 7234                    Nuristan : Wilayat - Province        298         442
# 9469                           Doro, Upper Nile State       2232        3384
# 5990                                           Djabal       1882        2128
# 13444                                             Van         51          57
# 15079                              Madinah : Province          0           *
# 15083                             Dakar/Thies : Point          6          17
# 12931                            Madaba : Governorate        984        1155
# 9475                                   Kosice : Point          5           5
# 9474                                      Humenne ETC          0           4
# 6874                                             Arar          0           0
#
#        Female 5-17 Female 12-17 Female 18-59 Female 60+  F: Unknown F: Total  \
# 8791           NaN          NaN            1        NaN         NaN        2
# 16655          NaN            0            0          0         0.0        0
# 12699          NaN            7            2          0         0.0       11
# 8597           NaN           12           32          1         NaN       76
# 2974        3489.0          NaN         5230        458         0.0    10187
# 12491          NaN            1            0          0         0.0        3
# 11828          NaN          785         1626         94         0.0     4238
# 1974           0.0          NaN            0          0        15.0       15
# 1267           3.0          NaN            5          0         0.0        9
# 2606           0.0          NaN            0          0         1.0        1
# 7234           NaN          268          739         38         0.0     1785
# 9469           NaN         2481         4724        233         0.0    13054
# 5990           NaN         1208         3716        317         NaN     9251
# 13444          NaN           33          240          4         0.0      385
# 15079          NaN            0            *          0         0.0        *
# 15083          NaN           16           29          *         0.0       69
# 12931          NaN          740         2682        215         0.0     5776
# 9475           NaN            0           12          0         NaN       22
# 9474           NaN            5           12          3         NaN       24
# 6874           NaN            0            0          0         0.0        0
#
#       Male 0-4 Male 5-11  Male 5-17 Male 12-17 Male 18-59 Male 60+  \
# 8791       NaN       NaN        NaN        NaN          5      NaN
# 16655        0         0        NaN          0          0        0
# 12699        1         4        NaN          9          0        0
# 8597        13        20        NaN          9         28        5
# 2974      1173       NaN     3561.0        NaN       5410      580
# 12491        0         0        NaN          0          1        0
# 11828      408      1290        NaN        955       2060      253
# 1974         0       NaN        0.0        NaN          0        0
# 1267         1       NaN        6.0        NaN         13        0
# 2606         0       NaN        0.0        NaN          1        0
# 7234       306       441        NaN        293        696       65
# 9469      2743      4720        NaN       3049       4893      250
# 5990      1882      2224        NaN       1113       2197      257
# 13444       43        64        NaN        104        454        7
# 15079        0         0        NaN          0          *        0
# 15083       10        25        NaN         20         58        *
# 12931      991      1229        NaN        800       2492      154
# 9475         2         1        NaN          1         38        1
# 9474         3         4        NaN          3         11        1
# 6874         0         0        NaN          0          1        0
#
#        M: Unknown M: Total
# 8791          NaN        5
# 16655         0.0        0
# 12699         0.0       14
# 8597          NaN       75
# 2974          0.0    10724
# 12491         0.0        1
# 11828         0.0     4966
# 1974         25.0       25
# 1267          0.0       20
# 2606          0.0        1
# 7234          0.0     1801
# 9469          0.0    15655
# 5990          NaN     7673
# 13444         0.0      672
# 15079         0.0        *
# 15083         0.0      116
# 12931         0.0     5666
# 9475          NaN       43
# 9474          NaN       22
# 6874          0.0        1

# %%
#Replacing the special characters and null values with zero.
demographics = demographics.fillna(0)
demographics=demographics.replace(['*'], [0])
demographics=demographics.replace([''], [0])
demographics.sample(20)
# Out:
#        Year Country / territory of asylum/residence  \
# 6445   2009                                   Gabon
# 17535  2016                                   Gabon
# 9961   2012                  Dem. Rep. of the Congo
# 1683   2003                                  Turkey
# 718    2002                                   Gabon
# 8640   2011                                Cameroon
# 14228  2015                                   Libya
# 15547  2015                                 Armenia
# 5212   2008                                 Armenia
# 8424   2011                             Afghanistan
# 6293   2009                    Central African Rep.
# 6385   2009                                    Cuba
# 7420   2010                                Cameroon
# 1171   2003                                  Angola
# 15054  2014                           Rep. of Korea
# 17585  2016                           Guinea-Bissau
# 10726  2012                             South Sudan
# 10857  2012                                  Turkey
# 11172  2013                                Cameroon
# 3437   2006                                Cameroon
#
#                                       Location Name Female 0-4 Female 5-11  \
# 6445                                       Fougamou          1           0
# 17535                               Okondja : Point          0           0
# 9961              Nord Kivu and Sud Kivu: Provinces       2913        6779
# 1683                                          Konya          2           0
# 718                                       Rinanzala         29           0
# 8640                                          Ngazi         22          21
# 14228  Libya : Dispersed in the country / territory       1019        2638
# 15547                  Aragatsotn : Marz - Province          0           0
# 5212                                   Charentsavan          0           0
# 8424                Badakhshan : Wilayat - Province         29         120
# 6293                                       Molangue         12          14
# 6385                            Ciudad de La Habana          0           0
# 7420                                       Meiganga        193         368
# 1171                                       Keutepwe         43           0
# 15054                                         Yeosu          0           0
# 17585                                        Mbaiam         27          33
# 10726                                          Lasu        711        1052
# 10857                            Isparta : Province         31          56
# 11172                                        Maroua          1           1
# 3437                         East/Adamaoua province       1864        2633
#
#        Female 5-17 Female 12-17 Female 18-59 Female 60+  F: Unknown F: Total  \
# 6445           0.0            0            2          0         0.0        3
# 17535          0.0            0            0          0         0.0        0
# 9961           0.0         4201         9441        395         0.0    23729
# 1683           4.0            0           14          0         0.0       20
# 718           27.0            0           55          4         0.0      115
# 8640           0.0           12           35          4         0.0       94
# 14228          0.0         1526         9346        521         0.0    15050
# 15547          0.0            0           39         18         0.0       57
# 5212           0.0            0            4          1         0.0        5
# 8424           0.0           62          178         10         0.0      399
# 6293           0.0           10           21          0         0.0       57
# 6385           0.0            0            5          0         0.0        5
# 7420           0.0          212          508         23         0.0     1304
# 1171          87.0            0          117         13         0.0      260
# 15054          0.0            0            0          0         0.0        0
# 17585          0.0           26           71         10         0.0      167
# 10726          0.0          667         1894        175         0.0     4499
# 10857          0.0           42          204          6         0.0      339
# 11172          0.0            1            9          1         0.0       13
# 3437           0.0         1423         4137        165         0.0    10222
#
#       Male 0-4 Male 5-11  Male 5-17 Male 12-17 Male 18-59 Male 60+  \
# 6445         0         1        0.0          0          4        0
# 17535        0         0        0.0          0         11        0
# 9961      3568      5002        0.0       4001       7025      189
# 1683         4         0        9.0          0         24        0
# 718         24         0       53.0          0         52        1
# 8640        13        23        0.0         11         26        0
# 14228     1045      2846        0.0       1910      15131      802
# 15547        0         0        0.0          0         32       10
# 5212         0         0        0.0          0          4        0
# 8424        30       117        0.0        116        844       22
# 6293        10         9        0.0          7         27        2
# 6385         0         1        0.0          0         11        0
# 7420       220       420        0.0        201        378       43
# 1171        35         0       70.0          0         94       11
# 15054        0         0        0.0          0          0        0
# 17585       21        34        0.0         24         44        5
# 10726      685      1004        0.0        679       1423      106
# 10857       53        63        0.0         56        223        4
# 11172        0         0        0.0          3          4        0
# 3437      1890      2792        0.0       1284       3798      433
#
#        M: Unknown M: Total
# 6445          0.0        5
# 17535         0.0       13
# 9961          0.0    19785
# 1683          0.0       37
# 718           0.0      130
# 8640          0.0       73
# 14228         0.0    21734
# 15547         0.0       42
# 5212          0.0        4
# 8424          0.0     1129
# 6293          0.0       55
# 6385          0.0       12
# 7420          0.0     1262
# 1171          0.0      210
# 15054         0.0        0
# 17585         0.0      128
# 10726         0.0     3897
# 10857         0.0      399
# 11172         0.0        7
# 3437          0.0    10197

# %%
#Retrieving the column names for reference
demographics.columns
# Out:
# Index(['Year', 'Country / territory of asylum/residence', 'Location Name',
#        'Female 0-4', 'Female 5-11', 'Female 5-17', 'Female 12-17',
#        'Female 18-59', 'Female 60+', 'F: Unknown', 'F: Total', 'Male 0-4',
#        'Male 5-11', 'Male 5-17', 'Male 12-17', 'Male 18-59', 'Male 60+',
#        'M: Unknown', 'M: Total'],
#       dtype='object')

# %%
#Renaming the column names in the standard format that is required in the database
labels= ['year', 'host_country', 'location_name',
       'female_0_4', 'female_5_11', 'female_5_17', 'female_12_17',
       'female_18_59', 'female_60plus', 'f_unknown', 'f_total', 'male_0_4',
       'male_5_11', 'male_5_17', 'male_12_17', 'male_18_59', 'male_60plus',
       'm_unknown', 'm_total']
demographics.columns = labels
demographics
# Out:
#        year host_country                                  location_name  \
# 0      2001  Afghanistan                                          Kabul
# 1      2001  Afghanistan                                        Various
# 2      2001  Afghanistan                                          Herat
# 3      2001       Angola                                          Viana
# 4      2001       Angola                                         Moxico
# ...     ...          ...                                            ...
# 18351  2016       Zambia                           Mayukwayukwa : Point
# 18352  2016       Zambia                                 Meheba : Point
# 18353  2016       Zambia  Zambia : Dispersed in the country / territory
# 18354  2016     Zimbabwe                                  Harare : City
# 18355  2016     Zimbabwe                          Manicaland : Province
#
#       female_0_4 female_5_11  female_5_17 female_12_17 female_18_59  \
# 0              0           0          1.0            0            1
# 1          14335           0      45451.0            0        99880
# 2              0           0          0.0            0            1
# 3            484           0       1687.0            0         1282
# 4            219           0        734.0            0          427
# ...          ...         ...          ...          ...          ...
# 18351        983        1456          0.0          934         2878
# 18352       1248        2364          0.0         1598         4182
# 18353        637        1444          0.0          979         2712
# 18354        220         117          0.0           82          296
# 18355        496         769          0.0          525         1450
#
#       female_60plus  f_unknown f_total male_0_4 male_5_11  male_5_17  \
# 0                 0        0.0       2        0         0        0.0
# 1             19234   412004.0  590904    14716         0    47522.0
# 2                 0        0.0       1        0         0        0.0
# 3                43        0.0    3496      597         0     1645.0
# 4                25        0.0    1405      226         0      711.0
# ...             ...        ...     ...      ...       ...        ...
# 18351           157        0.0    6408      982      1416        0.0
# 18352           300        0.0    9692     1205      2367        0.0
# 18353           400        0.0    6172      602      1314        0.0
# 18354            11        0.0     726      204       115        0.0
# 18355            58        0.0    3298      462       829        0.0
#
#       male_12_17 male_18_59 male_60plus  m_unknown m_total
# 0              0          2           0        0.0       2
# 1              0     114965       13025   435492.0  625720
# 2              0          1           0        0.0       1
# 3              0        787          34        0.0    3063
# 4              0        139          15        0.0    1091
# ...          ...        ...         ...        ...     ...
# 18351        903       3202         326        0.0    6829
# 18352       1693       4963         467        0.0   10695
# 18353       1018       2786         512        0.0    6232
# 18354         91        432          11        0.0     853
# 18355        604       1688          42        0.0    3625
#
# [18356 rows x 19 columns]

# %%
#Dropping unwanted columns
demographics.drop(['female_0_4','female_5_11','female_5_17','female_12_17',
       'female_18_59', 'female_60plus', 'f_unknown','male_0_4',
       'male_5_11', 'male_5_17', 'male_12_17', 'male_18_59', 'male_60plus',
       'm_unknown', 'location_name'],axis =1,inplace = True)
demographics
# Out:
#        year host_country f_total m_total
# 0      2001  Afghanistan       2       2
# 1      2001  Afghanistan  590904  625720
# 2      2001  Afghanistan       1       1
# 3      2001       Angola    3496    3063
# 4      2001       Angola    1405    1091
# ...     ...          ...     ...     ...
# 18351  2016       Zambia    6408    6829
# 18352  2016       Zambia    9692   10695
# 18353  2016       Zambia    6172    6232
# 18354  2016     Zimbabwe     726     853
# 18355  2016     Zimbabwe    3298    3625
#
# [18356 rows x 4 columns]

# %%
#Verifying the datatypes of the columns 
demographics.dtypes
# Out:
# year             int64
# host_country    object
# f_total         object
# m_total         object
# dtype: object

# %%
#Converting the total columns to integer to get the sum in the groupby function
demographics['f_total'] =pd.to_numeric(demographics['f_total'])
demographics['m_total'] =pd.to_numeric(demographics['m_total'])
demographics.dtypes
# Out:
# year             int64
# host_country    object
# f_total          int64
# m_total          int64
# dtype: object

# %%
#Grouping by year and host country to arrive at the total male and female asylum seekers
group_year_demographics = demographics.groupby(['year','host_country']).sum().reset_index()
print(group_year_demographics)
# Out:
#       year                        host_country  f_total  m_total
# 0     2001                         Afghanistan   590907   625723
# 1     2001                             Albania      157      188
# 2     2001                             Algeria    76106    79324
# 3     2001                              Angola     6387     5863
# 4     2001                           Argentina      337      611
# ...    ...                                 ...      ...      ...
# 2087  2016                          Uzbekistan       10       17
# 2088  2016  Venezuela (Bolivarian Republic of)     4195     5424
# 2089  2016                               Yemen  1643680  1634329
# 2090  2016                              Zambia    26826    30381
# 2091  2016                            Zimbabwe     4024     4478
#
# [2092 rows x 4 columns]

# %%
#Converting the group by object into a dataframe
group_year_demographics_df = pd.DataFrame(group_year_demographics)
group_year_demographics_df
# Out:
#       year                        host_country  f_total  m_total
# 0     2001                         Afghanistan   590907   625723
# 1     2001                             Albania      157      188
# 2     2001                             Algeria    76106    79324
# 3     2001                              Angola     6387     5863
# 4     2001                           Argentina      337      611
# ...    ...                                 ...      ...      ...
# 2087  2016                          Uzbekistan       10       17
# 2088  2016  Venezuela (Bolivarian Republic of)     4195     5424
# 2089  2016                               Yemen  1643680  1634329
# 2090  2016                              Zambia    26826    30381
# 2091  2016                            Zimbabwe     4024     4478
#
# [2092 rows x 4 columns]

# %%
#Final demographics dataframe
final_demographics = group_year_demographics_df.copy()
final_demographics
# Out:
#       year                        host_country  f_total  m_total
# 0     2001                         Afghanistan   590907   625723
# 1     2001                             Albania      157      188
# 2     2001                             Algeria    76106    79324
# 3     2001                              Angola     6387     5863
# 4     2001                           Argentina      337      611
# ...    ...                                 ...      ...      ...
# 2087  2016                          Uzbekistan       10       17
# 2088  2016  Venezuela (Bolivarian Republic of)     4195     5424
# 2089  2016                               Yemen  1643680  1634329
# 2090  2016                              Zambia    26826    30381
# 2091  2016                            Zimbabwe     4024     4478
#
# [2092 rows x 4 columns]

# %%
#Reading the third dataset using pandas
time_series = pd.read_csv("Resources/time_series.csv")
time_series.sample(20)
# Out:
# C:\Users\vijet\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Year    Country / territory of asylum/residence  \
# 3945    1987                                   Colombia
# 250708  2016                                Afghanistan
# 132100  2012                              Rep. of Korea
# 143238  2013                                     Jordan
# 41060   2002                                       Mali
# 225755  2015                                    Ireland
# 242734  2015                                   Slovakia
# 80076   2007                                     Mexico
# 90149   2008  The former Yugoslav Republic of Macedonia
# 107020  2010                                    Germany
# 38059   2002                                     Canada
# 275595  2016                                      Italy
# 116467  2011                                     Canada
# 161379  2014                                 Czech Rep.
# 1046    1973                                    Morocco
# 13099   1995                                 Uzbekistan
# 121959  2011                                   Malaysia
# 183991  2014                                 Montenegro
# 21809   1999                                  Australia
# 85780   2008                              Côte d'Ivoire
#
#                           Origin                           Population type  \
# 3945                       Chile  Refugees (incl. refugee-like situations)
# 250708               Afghanistan                            Asylum-seekers
# 132100             Côte d'Ivoire                            Asylum-seekers
# 143238                      Mali                            Asylum-seekers
# 41060       Central African Rep.  Refugees (incl. refugee-like situations)
# 225755                      Cuba                         Others of concern
# 242734               Afghanistan                                 Stateless
# 80076   United States of America                            Asylum-seekers
# 90149                  Stateless                            Asylum-seekers
# 107020             Liechtenstein                            Asylum-seekers
# 38059                     Greece                            Asylum-seekers
# 275595                 Sri Lanka                         Others of concern
# 116467                  Paraguay                            Asylum-seekers
# 161379            Dominican Rep.                                 Returnees
# 1046                  Czech Rep.  Refugees (incl. refugee-like situations)
# 13099                 Tajikistan  Refugees (incl. refugee-like situations)
# 121959                  Cambodia  Refugees (incl. refugee-like situations)
# 183991                     Sudan                            Asylum-seekers
# 21809                     France  Refugees (incl. refugee-like situations)
# 85780              Côte d'Ivoire                             Returned IDPs
#
#         Value
# 3945      180
# 250708      0
# 132100      9
# 143238      1
# 41060       1
# 225755      0
# 242734      0
# 80076       1
# 90149       1
# 107020      1
# 38059      18
# 275595      0
# 116467      6
# 161379      0
# 1046       60
# 13099       3
# 121959     47
# 183991      0
# 21809       9
# 85780   25092

# %%
#Retrieving the column names for reference
time_series.columns
# Out:
# Index(['Year', 'Country / territory of asylum/residence', 'Origin',
#        'Population type', 'Value'],
#       dtype='object')

# %%
#Renaming the column names in the standard format that is required in the database
labels2= ['year', 'host_country', 'origin','population_type', 'value']
time_series.columns = labels2
#Replacing the special characters
time_series=time_series.replace(['*'], [0])
time_series
# Out:
#         year host_country           origin  \
# 0       1951    Australia  Various/Unknown
# 1       1951      Austria  Various/Unknown
# 2       1951      Belgium  Various/Unknown
# 3       1951       Canada  Various/Unknown
# 4       1951  Switzerland  Various/Unknown
# ...      ...          ...              ...
# 298436  2016     Zimbabwe         Zimbabwe
# 298437  2016     Zimbabwe         Zimbabwe
# 298438  2016     Zimbabwe         Zimbabwe
# 298439  2016     Zimbabwe         Zimbabwe
# 298440  2016     Zimbabwe         Zimbabwe
#
#                                  population_type   value
# 0       Refugees (incl. refugee-like situations)  180000
# 1       Refugees (incl. refugee-like situations)  282000
# 2       Refugees (incl. refugee-like situations)   55000
# 3       Refugees (incl. refugee-like situations)  168511
# 4       Refugees (incl. refugee-like situations)   10000
# ...                                          ...     ...
# 298436                         Others of concern     128
# 298437                             Returned IDPs       0
# 298438  Refugees (incl. refugee-like situations)       0
# 298439                                 Returnees       0
# 298440                                 Stateless       0
#
# [298441 rows x 5 columns]

# %%
#Dropping unwanted column
time_series.drop(['population_type'],axis =1,inplace = True)
time_series
# Out:
#         year host_country           origin   value
# 0       1951    Australia  Various/Unknown  180000
# 1       1951      Austria  Various/Unknown  282000
# 2       1951      Belgium  Various/Unknown   55000
# 3       1951       Canada  Various/Unknown  168511
# 4       1951  Switzerland  Various/Unknown   10000
# ...      ...          ...              ...     ...
# 298436  2016     Zimbabwe         Zimbabwe     128
# 298437  2016     Zimbabwe         Zimbabwe       0
# 298438  2016     Zimbabwe         Zimbabwe       0
# 298439  2016     Zimbabwe         Zimbabwe       0
# 298440  2016     Zimbabwe         Zimbabwe       0
#
# [298441 rows x 4 columns]

# %%
#Verifying the datatypes
time_series.dtypes
# Out:
# year             int64
# host_country    object
# origin          object
# value           object
# dtype: object

# %%
#Converting the data type to numeric for the Value column
time_series['value'] =pd.to_numeric(time_series['value'])
time_series.dtypes
# Out:
# year             int64
# host_country    object
# origin          object
# value            int64
# dtype: object

# %%
#Grouping by year, host country and origin to arrive at the total value
year_group_timeseries = time_series.groupby(['year', 'host_country', 'origin']).sum().reset_index()
year_group_timeseries
# Out:
#         year          host_country            origin   value
# 0       1951             Australia   Various/Unknown  180000
# 1       1951               Austria   Various/Unknown  282000
# 2       1951               Belgium   Various/Unknown   55000
# 3       1951                Canada   Various/Unknown  168511
# 4       1951  China, Hong Kong SAR   Various/Unknown   30000
# ...      ...                   ...               ...     ...
# 123550  2016              Zimbabwe      South Africa       7
# 123551  2016              Zimbabwe             Sudan       5
# 123552  2016              Zimbabwe  Syrian Arab Rep.       0
# 123553  2016              Zimbabwe            Uganda       7
# 123554  2016              Zimbabwe          Zimbabwe     128
#
# [123555 rows x 4 columns]

# %%
#Sorting the dataframe to arrive at the total count of asylum seekers over the years base on value(total count)
sorted_timeseries = time_series.sort_values("value", ascending =False).reset_index(drop=True)
sorted_timeseries.head()
# Out:
#    year      host_country            origin    value
# 0  2014  Syrian Arab Rep.  Syrian Arab Rep.  7632500
# 1  2016          Colombia          Colombia  7410816
# 2  2015          Colombia          Colombia  6939067
# 3  2015  Syrian Arab Rep.  Syrian Arab Rep.  6563462
# 4  2013  Syrian Arab Rep.  Syrian Arab Rep.  6520800

# %%
#Top 25 countries showing the highest number of asylum seekers
final_timeseries = sorted_timeseries[:25]
final_timeseries
# Out:
#     year            host_country            origin    value
# 0   2014        Syrian Arab Rep.  Syrian Arab Rep.  7632500
# 1   2016                Colombia          Colombia  7410816
# 2   2015                Colombia          Colombia  6939067
# 3   2015        Syrian Arab Rep.  Syrian Arab Rep.  6563462
# 4   2013        Syrian Arab Rep.  Syrian Arab Rep.  6520800
# 5   2016        Syrian Arab Rep.  Syrian Arab Rep.  6325978
# 6   2014                Colombia          Colombia  6044151
# 7   2013                Colombia          Colombia  5368138
# 8   2015                    Iraq              Iraq  4403287
# 9   2012                Colombia          Colombia  3943509
# 10  2011                Colombia          Colombia  3888309
# 11  2010                Colombia          Colombia  3672054
# 12  2016                    Iraq              Iraq  3604285
# 13  2014                    Iraq              Iraq  3596356
# 14  2009                Thailand          Thailand  3500000
# 15  2008                Thailand          Thailand  3500000
# 16  2006                   Nepal             Nepal  3400000
# 17  2009                Colombia          Colombia  3303979
# 18  1989                Pakistan       Afghanistan  3272290
# 19  1988                Pakistan       Afghanistan  3254393
# 20  1990                Pakistan       Afghanistan  3253000
# 21  2015                   Sudan             Sudan  3218234
# 22  1991  Iran (Islamic Rep. of)       Afghanistan  3186616
# 23  1987                Pakistan       Afghanistan  3156000
# 24  1991                Pakistan       Afghanistan  3098000

# %% [markdown]
# ### Create connection to the database.

# %%
#Creating the postgres connection
connection_string = "postgresql+psycopg2://rapsyeeaxuvfue:8f005c52901b9f13766f6cf78da8e777e626ae88c6540cd4254fcb53bed2d9df@ec2-107-22-83-3.compute-1.amazonaws.com:5432/d84575gjd8j2q1"
engine = create_engine(connection_string)

# %%
# Confirm tables
engine.table_names()
# Out:
# ['demographics', 'time_series']

# %% [markdown]
# ### Load the final DataFrame into the database.

# %%
#The data from the final dataframe is loaded to the database
final_demographics.to_sql(name='demographics', con=engine, if_exists='append', index =True)
final_timeseries.to_sql(name='time_series', con=engine, if_exists='append', index =True)
